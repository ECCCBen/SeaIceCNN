# %% [markdown]
# ## This code reads all the classified RSAT-2 images for Coronation Gulf between 2008 and 2020 and creates weekly mosaics of the mean value of overlaping pixels and the value closest to the valid date of the weekly CIS regional charts (Mondays at 6PM UTC)
#
# Note: all RSAT-2 outputs have been projected to the EASE-GRID 2 projection (EPSG:6931), i.e. all pixels have the same size which was set to the pixel spacing of RSAT-2 SCWA images (50m) and are perfectly aligned.

# %%
from os import walk
from os.path import join
import numpy as np
import gdal
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# Reads all the files and generates a datetime array associated with the filenames to sort the images by weeks

# %%
indir = r'../../data'
outdir = r'../../data'

images = [join(root, f) for root, dirs, files in walk(indir) for f in files if f.endswith('.tif') and f.startswith('R2S0_4Class')]
dates = pd.DataFrame({'Dates':[]})
for image in images:
    
    dates = dates.append(pd.Series({'Dates':pd.to_datetime(datetime.strptime(image.split('_')[8] + image.split('_')[9], '%Y%m%d%H%M%S'))}), ignore_index = True)

dates['Filenames'] = images

del images

# %% [markdown]
# Initiates the first week and the dataframe

# %%
curday = datetime(2008,7,14,23,0,0)

weeklydf = pd.DataFrame({'Date (YYYY-MM-DD)':[], '# Images': [], 'Total # of Pixels': [], 
                         'Mean # Ice Pixels': [], 'Mean Ice Concentration (%)': [],
                         'Mosaic # Ice Pixels': [], 'Mosaic Ice Concentration (%)': []})

# %% [markdown]
# Until the date is below July 31 2020, this code reads the images for a given week, mosaics the images, calculates the number of pixels and the total concentration for Coronation Gulf. The mosaiced outputs are saved as a gif.

# %%
while curday < datetime(2020,7,31):

    print(curday.strftime('%Y-%m-%d'))
    
    tempdates = dates.loc[(dates.Dates <= curday) & (dates.Dates > curday - timedelta(7))].reset_index()
    tempdates.sort_values(by=['Dates'])
    
    if not tempdates.Filenames.empty:
        
        
        
        for filename in tempdates.Filenames:
            
            if tempdates.Filenames[tempdates.Filenames == filename].index == 0:
                
                tempimg = gdal.Open(join(indir, filename))
                temparray = tempimg.GetRasterBand(1).ReadAsArray()
                mosaicarray = tempimg.GetRasterBand(1).ReadAsArray()
                
            else:
                
                tempimg = None
                del tempimg
                
                tempimg = gdal.Open(join(indir, filename))
                newtemparray = tempimg.GetRasterBand(1).ReadAsArray()
                temparray = np.dstack([temparray, newtemparray])
                mosaicarray[np.isnan(newtemparray) == False] = newtemparray[np.isnan(newtemparray) == False]
                
                del newtemparray
        
        if len(temparray.shape) == 3:
        
            meanarray = np.nanmean(temparray, axis=2)
            
        else:
            
            meanarray = temparray
            
        del temparray
        
        print('Updating database...')
        
        tempseries = pd.Series({'Date (YYYY-MM-DD)': curday.strftime('%Y-%m-%d'),
                                '# Images': len(meanarray[np.isnan(meanarray)==False]),
                                'Total # of Pixels': len(meanarray[np.isnan(meanarray)==False]),
                                'Mean # Ice Pixels': len(meanarray[(np.isnan(meanarray)==False) & (meanarray<=0.5)]),
                                'Mean Ice Concentration (%)': (len(meanarray[(np.isnan(meanarray)==False) & (meanarray<=0.5)]) / len(meanarray[np.isnan(meanarray)==False]) * 100),
                                'Mosaic # Ice Pixels': len(mosaicarray[(np.isnan(mosaicarray)==False) & (mosaicarray<=0.5)]),
                                'Mosaic Ice Concentration (%)': (len(mosaicarray[(np.isnan(mosaicarray)==False) & (mosaicarray<=0.5)]) / len(mosaicarray[np.isnan(meanarray)==False]) * 100 )})
                                
        weeklydf = weeklydf.append(tempseries, ignore_index = True)
        
        print('Creating Mean Image...')
        
        driver = gdal.GetDriverByName('GTiff')
        driver.Register()    
        outmeanimg = driver.Create(join(outdir, 'WeeklyMean_' + curday.strftime('%Y%m%d') + '.tif'),
                        np.shape(meanarray)[1], np.shape(meanarray)[0], 1, gdal.GDT_Float32)
        
        geoTransform = tempimg.GetGeoTransform()
        outmeanimg.SetGeoTransform(geoTransform)
        proj = tempimg.GetProjection()
        outmeanimg.SetProjection(proj)
        
        outband = outmeanimg.GetRasterBand(1)
        outband.WriteArray(meanarray, 0, 0)
        
        outband= None
        outmeanimg = None
        driver = None
        meanarray = None
        
        del outband, outmeanimg, driver
    
        print('Creating Mosaic Image...')
    
        driver = gdal.GetDriverByName('GTiff')
        driver.Register()    
        outmosaicimg = driver.Create(join(outdir, 'WeeklyMosaic_' + curday.strftime('%Y%m%d') + '.tif'),
                        np.shape(mosaicarray)[1], np.shape(mosaicarray)[0], 1, gdal.GDT_Float32)
        
        geoTransform = tempimg.GetGeoTransform()
        outmosaicimg.SetGeoTransform(geoTransform)
        proj = tempimg.GetProjection()
        outmosaicimg.SetProjection(proj)
        
        outband = outmosaicimg.GetRasterBand(1)
        outband.WriteArray(mosaicarray, 0, 0)
        
        outband= None
        outmosaicimg = None
        driver = None
        mosaicarray = None
        tempimg = None
        
        del tempimg, outband, outmosaicimg, driver, mosaicarray, tempseries, tempdates
        
    else:
        
        print('No images for this week, updating database...')
        
        tempseries = pd.Series({'Date (YYYY-MM-DD)': curday.strftime('%Y-%m-%d'),
                                '# Images': 0,
                                'Total # of Pixels': np.nan,
                                'Mean # Ice Pixels': np.nan,
                                'Mean Ice Concentration (%)': np.nan,
                                'Mosaic # Ice Pixels': np.nan,
                                'Mosaic Ice Concentration (%)': np.nan})
                                
        weeklydf = weeklydf.append(tempseries, ignore_index = True)
        
        del tempseries, tempdates
    
    curday += timedelta(7)
# Out:
# 2008-07-14
# Updating database...
# C:\Users\bmontpetit\AppData\Local\Continuum\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:47: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\bmontpetit\AppData\Local\Continuum\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\bmontpetit\AppData\Local\Continuum\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in less_equal
# C:\Users\bmontpetit\AppData\Local\Continuum\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: invalid value encountered in less_equal
# Creating Mean Image...
# Creating Mosaic Image...
# 2008-07-21
# No images for this week, updating database...
# 2008-07-28
# C:\Users\bmontpetit\AppData\Local\Continuum\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2008-08-04
# No images for this week, updating database...
# 2008-08-11
# No images for this week, updating database...
# 2008-08-18
# No images for this week, updating database...
# 2008-08-25
# No images for this week, updating database...
# 2008-09-01
# No images for this week, updating database...
# 2008-09-08
# No images for this week, updating database...
# 2008-09-15
# No images for this week, updating database...
# 2008-09-22
# No images for this week, updating database...
# 2008-09-29
# No images for this week, updating database...
# 2008-10-06
# No images for this week, updating database...
# 2008-10-13
# No images for this week, updating database...
# 2008-10-20
# No images for this week, updating database...
# 2008-10-27
# No images for this week, updating database...
# 2008-11-03
# No images for this week, updating database...
# 2008-11-10
# No images for this week, updating database...
# 2008-11-17
# No images for this week, updating database...
# 2008-11-24
# No images for this week, updating database...
# 2008-12-01
# No images for this week, updating database...
# 2008-12-08
# No images for this week, updating database...
# 2008-12-15
# No images for this week, updating database...
# 2008-12-22
# No images for this week, updating database...
# 2008-12-29
# No images for this week, updating database...
# 2009-01-05
# No images for this week, updating database...
# 2009-01-12
# No images for this week, updating database...
# 2009-01-19
# No images for this week, updating database...
# 2009-01-26
# No images for this week, updating database...
# 2009-02-02
# No images for this week, updating database...
# 2009-02-09
# No images for this week, updating database...
# 2009-02-16
# No images for this week, updating database...
# 2009-02-23
# No images for this week, updating database...
# 2009-03-02
# No images for this week, updating database...
# 2009-03-09
# No images for this week, updating database...
# 2009-03-16
# No images for this week, updating database...
# 2009-03-23
# No images for this week, updating database...
# 2009-03-30
# No images for this week, updating database...
# 2009-04-06
# No images for this week, updating database...
# 2009-04-13
# No images for this week, updating database...
# 2009-04-20
# No images for this week, updating database...
# 2009-04-27
# No images for this week, updating database...
# 2009-05-04
# No images for this week, updating database...
# 2009-05-11
# No images for this week, updating database...
# 2009-05-18
# No images for this week, updating database...
# 2009-05-25
# No images for this week, updating database...
# 2009-06-01
# No images for this week, updating database...
# 2009-06-08
# No images for this week, updating database...
# 2009-06-15
# No images for this week, updating database...
# 2009-06-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-06-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-07-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-07-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-07-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-07-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-08-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-08-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-08-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-08-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-08-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-09-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-09-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-09-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-09-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-10-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-10-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-10-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-10-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-11-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-11-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-11-16
# No images for this week, updating database...
# 2009-11-23
# No images for this week, updating database...
# 2009-11-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-12-07
# No images for this week, updating database...
# 2009-12-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-12-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2009-12-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-01-04
# No images for this week, updating database...
# 2010-01-11
# No images for this week, updating database...
# 2010-01-18
# No images for this week, updating database...
# 2010-01-25
# No images for this week, updating database...
# 2010-02-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-02-08
# No images for this week, updating database...
# 2010-02-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-02-22
# No images for this week, updating database...
# 2010-03-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-03-08
# No images for this week, updating database...
# 2010-03-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-03-22
# No images for this week, updating database...
# 2010-03-29
# No images for this week, updating database...
# 2010-04-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-04-12
# No images for this week, updating database...
# 2010-04-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-04-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-05-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-05-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-05-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-05-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-05-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-06-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-06-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-06-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-06-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-07-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-07-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-07-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-07-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-08-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-08-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-08-16
# No images for this week, updating database...
# 2010-08-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-08-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-09-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-09-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-09-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-09-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-10-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-10-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-10-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-10-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-11-01
# No images for this week, updating database...
# 2010-11-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-11-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-11-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-11-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-12-06
# No images for this week, updating database...
# 2010-12-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-12-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2010-12-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-01-03
# No images for this week, updating database...
# 2011-01-10
# No images for this week, updating database...
# 2011-01-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-01-24
# No images for this week, updating database...
# 2011-01-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-02-07
# No images for this week, updating database...
# 2011-02-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-02-21
# No images for this week, updating database...
# 2011-02-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-03-07
# No images for this week, updating database...
# 2011-03-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-03-21
# No images for this week, updating database...
# 2011-03-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-04-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-04-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-04-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-04-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-05-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-05-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-05-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-05-23
# No images for this week, updating database...
# 2011-05-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-06-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-06-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-06-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-06-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-07-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-07-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-07-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-07-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-08-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-08-08
# No images for this week, updating database...
# 2011-08-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-08-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-08-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-09-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-09-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-09-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-09-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-10-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-10-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-10-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-10-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-10-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-11-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-11-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-11-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-11-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-12-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-12-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-12-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2011-12-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-01-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-01-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-01-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-01-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-01-30
# No images for this week, updating database...
# 2012-02-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-02-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-02-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-02-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-03-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-03-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-03-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-03-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-04-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-04-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-04-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-04-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-04-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-05-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-05-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-05-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-05-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-06-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-06-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-06-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-06-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-07-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-07-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-07-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-07-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-07-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-08-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-08-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-08-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-08-27
# No images for this week, updating database...
# 2012-09-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-09-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-09-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-09-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-10-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-10-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-10-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-10-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-10-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-11-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-11-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-11-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-11-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-12-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-12-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-12-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-12-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2012-12-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-01-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-01-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-01-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-01-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-02-04
# No images for this week, updating database...
# 2013-02-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-02-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-02-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-03-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-03-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-03-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-03-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-04-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-04-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-04-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-04-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-04-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-05-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-05-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-05-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-05-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-06-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-06-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-06-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-06-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-07-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-07-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-07-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-07-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-07-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-08-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-08-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-08-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-08-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-09-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-09-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-09-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-09-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-09-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-10-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-10-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-10-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-10-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-11-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-11-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-11-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-11-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-12-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-12-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-12-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-12-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2013-12-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-01-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-01-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-01-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-01-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-02-03
# No images for this week, updating database...
# 2014-02-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-02-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-02-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-03-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-03-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-03-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-03-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-03-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-04-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-04-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-04-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-04-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-05-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-05-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-05-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-05-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-06-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-06-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-06-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-06-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-06-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-07-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-07-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-07-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-07-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-08-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-08-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-08-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-08-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-09-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-09-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-09-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-09-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-09-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-10-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-10-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-10-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-10-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-11-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-11-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-11-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-11-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-12-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-12-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-12-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-12-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2014-12-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-01-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-01-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-01-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-01-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-02-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-02-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-02-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-02-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-03-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-03-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-03-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-03-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-03-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-04-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-04-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-04-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-04-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-05-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-05-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-05-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-05-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-06-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-06-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-06-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-06-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-06-29
# No images for this week, updating database...
# 2015-07-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-07-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-07-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-07-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-08-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-08-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-08-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-08-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-08-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-09-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-09-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-09-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-09-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-10-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-10-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-10-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-10-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-11-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-11-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-11-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-11-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-11-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-12-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-12-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-12-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2015-12-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-01-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-01-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-01-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-01-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-02-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-02-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-02-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-02-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-02-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-03-07
# No images for this week, updating database...
# 2016-03-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-03-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-03-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-04-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-04-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-04-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-04-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-05-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-05-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-05-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-05-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-05-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-06-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-06-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-06-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-06-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-07-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-07-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-07-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-07-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-08-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-08-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-08-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-08-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-08-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-09-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-09-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-09-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-09-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-10-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-10-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-10-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-10-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-10-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-11-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-11-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-11-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-11-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-12-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-12-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-12-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2016-12-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-01-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-01-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-01-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-01-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-01-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-02-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-02-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-02-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-02-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-03-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-03-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-03-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-03-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-04-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-04-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-04-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-04-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-05-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-05-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-05-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-05-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-05-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-06-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-06-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-06-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-06-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-07-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-07-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-07-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-07-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-07-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-08-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-08-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-08-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-08-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-09-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-09-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-09-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-09-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-10-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-10-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-10-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-10-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-10-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-11-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-11-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-11-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-11-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-12-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-12-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-12-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2017-12-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-01-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-01-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-01-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-01-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-01-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-02-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-02-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-02-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-02-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-03-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-03-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-03-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-03-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-04-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-04-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-04-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-04-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-04-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-05-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-05-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-05-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-05-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-06-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-06-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-06-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-06-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-07-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-07-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-07-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-07-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-07-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-08-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-08-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-08-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-08-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-09-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-09-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-09-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-09-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-10-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-10-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-10-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-10-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-10-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-11-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-11-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-11-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-11-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-12-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-12-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-12-17
# No images for this week, updating database...
# 2018-12-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2018-12-31
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-01-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-01-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-01-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-01-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-02-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-02-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-02-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-02-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-03-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-03-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-03-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-03-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-04-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-04-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-04-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-04-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-04-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-05-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-05-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-05-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-05-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-06-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-06-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-06-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-06-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-07-01
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-07-08
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-07-15
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-07-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-07-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-08-05
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-08-12
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-08-19
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-08-26
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-09-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-09-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-09-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-09-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-09-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-10-07
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-10-14
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-10-21
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-10-28
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-11-04
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-11-11
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-11-18
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-11-25
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-12-02
# No images for this week, updating database...
# 2019-12-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-12-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-12-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2019-12-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-01-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-01-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-01-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-01-27
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-02-03
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-02-10
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-02-17
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-02-24
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-03-02
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-03-09
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-03-16
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-03-23
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-03-30
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-04-06
# No images for this week, updating database...
# 2020-04-13
# No images for this week, updating database...
# 2020-04-20
# No images for this week, updating database...
# 2020-04-27
# No images for this week, updating database...
# 2020-05-04
# No images for this week, updating database...
# 2020-05-11
# No images for this week, updating database...
# 2020-05-18
# No images for this week, updating database...
# 2020-05-25
# No images for this week, updating database...
# 2020-06-01
# No images for this week, updating database...
# 2020-06-08
# No images for this week, updating database...
# 2020-06-15
# No images for this week, updating database...
# 2020-06-22
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-06-29
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-07-06
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-07-13
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-07-20
# Updating database...
# Creating Mean Image...
# Creating Mosaic Image...
# 2020-07-27
# No images for this week, updating database...

# %% [markdown]
# Saves the dataframe as a pickle

# %%
weeklydf.to_pickle(join(outdir, 'WeeklySIC_RSAT-2_20220329.pkl'))

# %%
weeklydf
# Out:
#     Date (YYYY-MM-DD)   # Images  Total # of Pixels  Mean # Ice Pixels  \
# 0          2008-07-14  5187600.0          5187600.0          4275600.0
# 1          2008-07-21        0.0                NaN                NaN
# 2          2008-07-28  7733200.0          7733200.0           420000.0
# 3          2008-08-04        0.0                NaN                NaN
# 4          2008-08-11        0.0                NaN                NaN
# ..                ...        ...                ...                ...
# 624        2020-06-29  7573600.0          7573600.0          7565600.0
# 625        2020-07-06  7739600.0          7739600.0          7460400.0
# 626        2020-07-13  7749200.0          7749200.0          6384000.0
# 627        2020-07-20  6562800.0          6562800.0          4851200.0
# 628        2020-07-27        0.0                NaN                NaN
#
#      Mean Ice Concentration (%)  Mosaic # Ice Pixels  \
# 0                     82.419616            4275600.0
# 1                           NaN                  NaN
# 2                      5.431128             453600.0
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ..                          ...                  ...
# 624                   99.894370            7555200.0
# 625                   96.392578            7173600.0
# 626                   82.382698            5741200.0
# 627                   73.919668            4990400.0
# 628                         NaN                  NaN
#
#      Mosaic Ice Concentration (%)
# 0                       82.419616
# 1                             NaN
# 2                        5.865618
# 3                             NaN
# 4                             NaN
# ..                            ...
# 624                     99.757051
# 625                     92.686961
# 626                     74.087648
# 627                     76.040714
# 628                           NaN
#
# [629 rows x 7 columns]

# %% [markdown]
# ## Added info: Timeseries of the Mean of superimposed pixels vs the latest weekly pixel value

# %%
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
myFmt = mdates.DateFormatter('%Y')


fig, ax1 = plt.subplots(figsize=(15,10))

ax1.plot(pd.to_datetime(weeklydf.dropna()['Date (YYYY-MM-DD)']), weeklydf.dropna()['Mean Ice Concentration (%)'])
ax1.plot(pd.to_datetime(weeklydf.dropna()['Date (YYYY-MM-DD)']), weeklydf.dropna()['Mosaic Ice Concentration (%)'], '-g')
ax1.set_xlabel('Year', fontsize=24, fontweight='bold')
ax1.set_ylabel('SIC (%)', fontsize=23, fontweight='bold')
ax1.legend(['Mean of\nweekly images','Mosaic of\nweekly images'], loc='center left', fontsize=22)
ax1.set_ylim(0,100)
# Out:
# (0, 100)

# %% [markdown]
# # Observations:
# 1. The mean is on average better than the latest. This can be explained by the multiple viewing angles over a given week giving better accuracy.
