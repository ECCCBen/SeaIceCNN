# %% [markdown]
# ## This code reads the 4D training/testing data arrays, calculates the mean and std values of each of the bands, gets the sample prediction from the trained CNN and saves it all into a Pandas dataframe

# %%
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import scipy
from scipy import signal
import xml.etree.ElementTree as ET
from tensorflow.keras.models import load_model

# %% [markdown]
# Function that takes the 4D input array normalizes the data and returns the ice/water prediction from the trained CNN

# %%
def class_data(X):
    
    classifier = load_model(r'Data\SeaIceCNN.h5')

    df = pd.read_pickle(r"Data\means_stds_S0_cnn.pkl")
    
    for i in range(X.shape[3]):
        
        X[:,:,:,i] = ((X[:,:,:,i] - df.means.iloc[i]) / df.stds.iloc[i]).astype(np.float64)
        
    return np.concatenate(classifier.predict(X, use_multiprocessing=True))

# %% [markdown]
# Load training ice data

# %%
icedata_temp = np.load(r"../../data/TrainingDataS0_ice.npy")

# %% [markdown]
# Create a dataframe with the mean values of HH, HV, incidence angle and NESZ as well as the standard deviation of HH and HV for each 20x20 pixel subsample

# %%
df = pd.DataFrame({'HH':np.mean(icedata_temp[:,:,:,0], axis=(1,2)),
                  'HV':np.mean(icedata_temp[:,:,:,1], axis=(1,2)),
                  'Angle':np.mean(icedata_temp[:,:,:,2], axis=(1,2)),
                  'NESZ':np.mean(icedata_temp[:,:,:,3], axis=(1,2)),
                  'std_HH':np.std(icedata_temp[:,:,:,0], axis=(1,2)),
                  'std_HV':np.std(icedata_temp[:,:,:,1], axis=(1,2)),
                  'cnn_prediction':class_data(icedata_temp)})

# %% [markdown]
# Load test ice data

# %%
icedata_temp = np.load(r"Data\ice\TestDataS0_ice.npy")

# %% [markdown]
# Append the test data to the training data in the dataframe

# %%
df = df.append(pd.DataFrame({'HH':np.mean(icedata_temp[:,:,:,0], axis=(1,2)),
                             'HV':np.mean(icedata_temp[:,:,:,1], axis=(1,2)),
                             'Angle':np.mean(icedata_temp[:,:,:,2], axis=(1,2)),
                             'NESZ':np.mean(icedata_temp[:,:,:,3], axis=(1,2)),
                             'std_HH':np.std(icedata_temp[:,:,:,0], axis=(1,2)),
                             'std_HV':np.std(icedata_temp[:,:,:,1], axis=(1,2)),
                             'cnn_prediction':class_data(icedata_temp)}))

# %% [markdown]
# Visualize a sample of the dataframe

# %%
df
# Out:
#                HH         HV      Angle       NESZ    std_HH    std_HV  \
# 0      -22.492740 -26.918483  34.264207 -27.714644  1.982386  1.564870
# 1      -20.969396 -26.996118  34.341420 -27.600618  2.010432  1.777341
# 2      -21.968216 -26.825797  34.330006 -27.617288  1.758554  1.568647
# 3      -21.939295 -26.659789  34.318641 -27.633948  2.169017  1.678374
# 4      -19.243611 -26.412118  34.407226 -27.521943  2.576842  1.666163
# ...           ...        ...        ...        ...       ...       ...
# 488164 -19.192999 -28.257697  33.421225 -29.335913  1.909879  1.833410
# 488165 -19.559911 -28.570370  33.416483 -29.341183  1.752549  1.577997
# 488166 -19.298317 -27.484139  33.494749 -29.210123  2.069412  1.662352
# 488167 -18.286854 -27.111409  33.490000 -29.219449  2.007544  1.598697
# 488168 -18.689720 -27.379710  33.485676 -29.227956  1.910235  1.825145
#
#         cnn_prediction
# 0             0.033171
# 1             0.011849
# 2             0.061063
# 3             0.004932
# 4             0.000064
# ...                ...
# 488164        0.002290
# 488165        0.972817
# 488166        0.000042
# 488167        0.075162
# 488168        0.001210
#
# [7703220 rows x 7 columns]

# %% [markdown]
# Save the dataframe to a pickle file

# %%
df.to_pickle(r'Data/AllIceDF.pkl')

# %% [markdown]
# Delete the numpy 4D array

# %%
del icedata_temp

# %% [markdown]
# Load the water training data

# %%
waterdata_temp = np.load(r"Data\water\TrainingDataS0_water.npy")

# %% [markdown]
# Generate the dataframe for the water subsamples

# %%
df = pd.DataFrame({'HH':np.mean(waterdata_temp[:,:,:,0], axis=(1,2)),
                  'HV':np.mean(waterdata_temp[:,:,:,1], axis=(1,2)),
                  'Angle':np.mean(waterdata_temp[:,:,:,2], axis=(1,2)),
                  'NESZ':np.mean(waterdata_temp[:,:,:,3], axis=(1,2)),
                  'std_HH':np.std(waterdata_temp[:,:,:,0], axis=(1,2)),
                  'std_HV':np.std(waterdata_temp[:,:,:,1], axis=(1,2)),
                  'cnn_prediction':class_data(waterdata_temp)})

# %% [markdown]
# Load the test water data

# %%
waterdata_temp = np.load(r"Data\water\TestDataS0_water.npy")

# %% [markdown]
# Append the test data to the training data in the dataframe

# %%
df = df.append(pd.DataFrame({'HH':np.mean(waterdata_temp[:,:,:,0], axis=(1,2)),
                             'HV':np.mean(waterdata_temp[:,:,:,1], axis=(1,2)),
                             'Angle':np.mean(waterdata_temp[:,:,:,2], axis=(1,2)),
                             'NESZ':np.mean(waterdata_temp[:,:,:,3], axis=(1,2)),
                             'std_HH':np.std(waterdata_temp[:,:,:,0], axis=(1,2)),
                             'std_HV':np.std(waterdata_temp[:,:,:,1], axis=(1,2)),
                             'cnn_prediction':class_data(waterdata_temp)}))

# %% [markdown]
# Save the water dataframe to a pickle file

# %%
df.to_pickle(r'Data/AllWaterDF.pkl')

# %% [markdown]
# Delete the water 4D numpy array and the temporary dataframe

# %%
del waterdata_temp, df

# %% [markdown]
# Load the two dataframes

# %%
dfice = pd.read_pickle(r'Data/AllIceDF.pkl')
dfwater = pd.read_pickle(r'Data/AllWaterDF.pkl')

# %% [markdown]
# Generate dataframes that are sorted into incidence angle "bins"

# %%
bins = np.arange(19, 51)

wat_ang = dfwater.groupby(pd.cut(dfwater['Angle'],bins=bins))
ice_ang = dfice.groupby(pd.cut(dfice['Angle'],bins=bins))

# %% [markdown]
# Create a curve for the NESZ of a SCWA image

# %%
m = ET.parse(r"E:\Git\SeaIceCNN\Data\RS2_OK9968_PK112693_DK109010_SCWA_20100213_004158_HH_HV_SGF\product.xml")
root = m.getroot()

for lut in root.iter('{http://www.rsi.ca/rs2/prod/xml/schemas}referenceNoiseLevel'):

    if lut.attrib['incidenceAngleCorrection'] == 'Sigma Nought':

        steps = int(lut.findall('{http://www.rsi.ca/rs2/prod/xml/schemas}stepSize')[0].text)
        first_value = int(lut.findall('{http://www.rsi.ca/rs2/prod/xml/schemas}pixelFirstNoiseValue')[0].text)
        noise = np.array(lut.findall('{http://www.rsi.ca/rs2/prod/xml/schemas}noiseLevelValues')[0].text.split(' '),np.float32)

gains_temp = np.zeros(10523, np.float32)
gains_temp[first_value::steps] = np.power(10, noise/10)
kernel = signal.triang(2*steps - 1)
gains_interp = 10 * np.log10(scipy.ndimage.filters.convolve(gains_temp, kernel, mode="constant"))

pref = root.tag.strip('product')
nearang = np.float32(root.find(pref + 'imageGenerationParameters').find(pref + 'sarProcessingInformation').find(pref + 'incidenceAngleNearRange').text)
farang = np.float32(root.find(pref + 'imageGenerationParameters').find(pref + 'sarProcessingInformation').find(pref + 'incidenceAngleFarRange').text)
incang = np.interp(np.arange(10523),[0,len(np.arange(10523))-1],[farang,nearang])

incang_norm = [(x - np.min(incang)) / (np.max(incang) - np.min(incang)) * (len(bins) - 2) + 1 for x in incang]

# %% [markdown]
# Create a polynomial curve to fit the datasets (see figures below)

# %%
from scipy.optimize import curve_fit
def func2(x, a, b, c):
    return a*x**2+b*x+c

# %% [markdown]
# ## Figure: Box plots of the mean HH distributions for all the subsamples
#
# ## Results: The polynomial fits with their correlation coefficients are provided

# %%
fig, ax1 = plt.subplots(figsize=(15,10))
bp1 = ax1.boxplot(ice_ang['HH'].unique(), whis = [5, 95], sym = '', 
            labels = bins[0:-1], positions = np.arange(0.8, len(bins)-0.2, 1), 
            widths = 0.3, patch_artist = True)
bp2 = ax1.boxplot(wat_ang['HH'].unique(), whis = [5, 95], sym = '',
            labels = bins[0:-1], positions = np.arange(1.2, len(bins), 1),
            widths = 0.3, patch_artist = True)

ice_hh_med = []
for med in bp1['medians']:
    ice_hh_med.append(med.get_ydata()[0])    
water_hh_med = []
for med in bp2['medians']:
    water_hh_med.append(med.get_ydata()[0])
popt, pcov = curve_fit(func2, bins[:-1], np.array(water_hh_med))
popt2, pcov2 = curve_fit(func2, bins[:-1], np.array(ice_hh_med))

r2_ice=1-np.sum((ice_hh_med-func2(bins[:-1],*popt2))**2)/np.sum((ice_hh_med-np.mean(ice_hh_med))**2)
r2_water=1-np.sum((water_hh_med-func2(bins[:-1],*popt))**2)/np.sum((water_hh_med-np.mean(water_hh_med))**2)

line1 = ax1.plot(np.arange(1.2, len(bins), 1), func2(bins[:-1],*popt), '-b', linewidth=2)
line2 = ax1.plot(np.arange(0.8, len(bins)-.2, 1), func2(bins[:-1],*popt2), '-g', linewidth=2)

for box in bp1['boxes']:
    box.set(facecolor = 'green')
    

for box in bp2['boxes']:
    box.set(facecolor = 'blue')
ax1.set_xlim(0,31)
ax1.set_xticks(np.arange(0, len(bins)+2,2))
ax1.set_xticklabels(np.arange(18, 51,2).tolist(), fontweight = 'bold', fontsize = 22)
ax1.set_ylim(-30,0)
ax1.set_yticklabels(['-30','-25','-20','-15','-10','-5','0'], fontweight = 'bold', fontsize = 22)
ax1.set_ylabel(r'$\sigma^0$ [HH] (dB)', fontsize = 26, fontweight = 'bold')
ax1.set_xlabel(r'Incidence Angle ($^O$)', fontsize = 26, fontweight = 'bold')
ax1.legend([bp1["boxes"][0], bp2["boxes"][0]], ['Ice', 'Water'], loc='upper right', fontsize=26)

print('\u03C3\u00b0[ice] = %5.3f\u03B8\u00b2 %5.3f\u03B8 %5.3f , R\u00b2=%5.3f' % tuple(np.append(popt2,r2_ice)))
print('\u03C3\u00b0[water] = %5.3f\u03B8\u00b2 %5.3f\u03B8 + %5.3f , R\u00b2=%5.3f' % tuple(np.append(popt,r2_water)))
# Out:
# σ°[ice] = 0.006θ² -0.632θ -4.885 , R²=0.995
# σ°[water] = 0.023θ² -2.263θ + 29.997 , R²=0.999

# %% [markdown]
# ## Observations:
# 1. Mid range incidence angles might not be the best to seperate ice from water since the distributions are very similar for the two classes
# 2. The two classes have very distinct polynomial fitting cuvres which can be used to normalize to a given incidence angle.
# 3. The normalization might not improve classification since it is not the same for each class if both classes are present within a given image.
# 4. There is a lot less variability in the mean values for the ice class than the water class, i.e. classification will be lower for water given the higher variability.
# 5. Not shown here but was a nice result in early stages of the study: calibrating the digital numbers of the image into sigma-nought is extremely important. If not calibrated, the mean values are very similar for both classes and this can be explained by the fact that both classes follow a similar trend with incidence angle, resulting in a stronger rescaling for water than ice.
# 6. The same observations and classification results are obtained for the different calibrations (sigma-, beta-, gamma-nought).

# %% [markdown]
# ## Figure: Same boxplots for the mean HV values of all the subsamples

# %%
fig2, ax2 = plt.subplots(figsize=(15,10))
bp3 = ax2.boxplot(ice_ang.HV.unique(), whis = [5, 95], sym = '', 
            labels = bins[0:-1], positions = np.arange(0.8, len(bins)-0.2, 1), 
            widths = 0.3, patch_artist = True)
bp4 = ax2.boxplot(wat_ang.HV.unique(), whis = [5, 95], sym = '',
            labels = bins[0:-1], positions = np.arange(1.2, len(bins), 1),
            widths = 0.3, patch_artist = True)
l1 = ax2.plot(incang_norm, gains_interp, '-r', linewidth = 3)

for box in bp3['boxes']:
    box.set(facecolor = 'green')
    

for box in bp4['boxes']:
    box.set(facecolor = 'blue')
ax2.set_xlim(0,31)
ax2.set_xticks(np.arange(0, len(bins)+2,2))
ax2.set_xticklabels(np.arange(18, 51,2).tolist(), fontweight = 'bold', fontsize = 22)
ax2.set_ylim(-32,-22)
ax2.set_yticklabels(np.arange(-32, -21, 2).tolist(), fontweight = 'bold', fontsize = 22)
ax2.set_ylabel(r'$\sigma^0$ [HV] (dB)', fontsize = 26, fontweight = 'bold')
ax2.set_xlabel(r'Incidence Angle ($^0$)', fontsize = 26, fontweight = 'bold')
ax2.legend([bp3["boxes"][0], bp4["boxes"][0], l1[0]], ['Ice', 'Water', 'Noise floor'], loc='upper right', fontsize=26)

# %% [markdown]
# ## Observations:
# 1. The values follow very closely the noise floor for both classes, i.e. HV is very senstive to noise.
# 2. Water is oftern loss in noise, i.e. classification results will be lower for water class.
# 3. Forgetting the noise aspect, there is some seperability between the distributions of the two classes, i.e. HV will provide additional information to improve classification.

# %% [markdown]
# ## Additional info: Boxplot for the standard deviation of HH for all subsamples

# %%
fig3, ax3 = plt.subplots(figsize=(15,10))
bp5 = ax3.boxplot(ice_ang.std_HH.unique(), whis = [5, 95], sym = '', 
            labels = bins[0:-1], positions = np.arange(0.8, len(bins)-0.2, 1), 
            widths = 0.3, patch_artist = True)
bp6 = ax3.boxplot(wat_ang.std_HH.unique(), whis = [5, 95], sym = '',
            labels = bins[0:-1], positions = np.arange(1.2, len(bins), 1),
            widths = 0.3, patch_artist = True)

for box in bp5['boxes']:
    box.set(facecolor = 'green')
    

for box in bp6['boxes']:
    box.set(facecolor = 'blue')
ax3.set_xlim(0,31)
ax3.set_xticks(np.arange(0, len(bins)+2,2))
ax3.set_xticklabels(np.arange(18, 51,2).tolist(), fontweight = 'bold', fontsize = 22)
ax3.set_ylim(1,3)
ax3.set_yticklabels(np.arange(1,3.25,0.25).tolist(), fontweight = 'bold', fontsize = 22)
ax3.set_ylabel(r'SD($\beta^0$ [HH]) (dB)', fontsize = 26, fontweight = 'bold')
ax3.set_xlabel(r'Incidence Angle ($^0$)', fontsize = 26, fontweight = 'bold')
ax3.legend([bp5["boxes"][0], bp6["boxes"][0]], ['Ice', 'Water'], loc='upper right', fontsize=26)

# %% [markdown]
# ## Observations:
# 1. Water shows more variability at low incidence angles (Bragg Scattering?)
# 2. The boxes are narrower for water than ice indicating that there might be less "structure" to identify in water subsamples than ice subsamples.
# 3. No significant variability with incidence angle for the ice class, i.e. "structure" is stable with incidence angle.

# %% [markdown]
# ## Additional info: Boxplot for the standard deviation of HV for all subsamples

# %%
fig4, ax4 = plt.subplots(figsize=(15,10))
bp7 = ax4.boxplot(ice_ang.std_HV.unique(), whis = [5, 95], sym = '', 
            labels = bins[0:-1], positions = np.arange(0.8, len(bins)-0.2, 1), 
            widths = 0.3, patch_artist = True)
bp8 = ax4.boxplot(wat_ang.std_HV.unique(), whis = [5, 95], sym = '',
            labels = bins[0:-1], positions = np.arange(1.2, len(bins), 1),
            widths = 0.3, patch_artist = True)

for box in bp7['boxes']:
    box.set(facecolor = 'green')
    

for box in bp8['boxes']:
    box.set(facecolor = 'blue')
ax4.set_xlim(0,31)
ax4.set_xticks(np.arange(0, len(bins)+2,2))
ax4.set_xticklabels(np.arange(18, 51,2).tolist(), fontweight = 'bold', fontsize = 22)
ax4.set_ylim(1,3)
ax4.set_yticklabels(np.arange(1,3.25,0.25).tolist(), fontweight = 'bold', fontsize = 22)
ax4.set_ylabel(r'SD($\beta^0$ [HV]) (dB)', fontsize = 26, fontweight = 'bold')
ax4.set_xlabel(r'Incidence Angle ($^0$)', fontsize = 26, fontweight = 'bold')
ax4.legend([bp7["boxes"][0], bp8["boxes"][0]], ['Ice', 'Water'], loc='upper right', fontsize=26)

# %% [markdown]
# ## Observations:
# 1. Not much variability with incidence angle for both classes.
# 2. Similar to HH, there seems to be more "structure" visible in HV for ice than water.
