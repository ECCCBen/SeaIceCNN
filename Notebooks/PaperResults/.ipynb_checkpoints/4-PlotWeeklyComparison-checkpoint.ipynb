# %% [markdown]
# # This code takes the weekly sea ice concentrations of the ASI passive microwave sea ice concentration products and RSAT-2 CNN ice/water classification and compares them to the CIS weekly regional charts for the area of Coronation Gulf between 2009 and 2020.

# %%
import pandas as pd
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from datetime import datetime
import numpy as np

# %% [markdown]
# Read the dataframes

# %%
cis = pd.read_pickle(r'../../data/WeeklySIC_CIS.pkl')
asi = pd.read_pickle(r'../../data/WeeklySIC_ASI.pkl')
r2 = pd.read_pickle(r'../../data/WeeklySIC_RSAT-2.pkl')

# %% [markdown]
# ## Figure: Time series of the sea ice concentration of Coronation Gulf for the CIS regional charts, the RSAT-2 CNN classification and ASI SIC products.

# %%
fig, ax = plt.subplots(figsize=(15,10))

ax.fill_between(cis['Date'],cis['SIC'])
ax.plot(asi['Date (YYYY-MM-DD)'],asi['Mean Ice Concentration (%)'],color='orange', linewidth=2)
ax.plot(pd.to_datetime(r2['Date (YYYY-MM-DD)']),r2['Mean Ice Concentration (%)'],'+k', markeredgewidth=2)
ax.set_ylim(0,120)
ax.set_xlim(datetime(2008,6,1), datetime(2020,8,31))
ax.set_xticklabels(np.arange(2008,2022,2).tolist(),fontsize=24,fontweight='bold')
ax.set_yticklabels(np.arange(0,120,20),fontsize=24,fontweight='bold')
ax.legend(['ASI', 'RSAT-2', 'CIS'], fontsize=22, loc='upper center', ncol=3)
ax.set_ylabel('SIC (%)', fontsize=24, fontweight='bold')
# Out:
# Text(0, 0.5, 'SIC (%)')

# %% [markdown]
# ## Results: Mean bias and RMSE between the RSAT-2/ASI products and the CIS charts as reference

# %%
bias_r2=np.array([])
bias_asi=np.array([])

for i in range(len(cis)):
    
    date=pd.to_datetime(cis.iloc[i]['Date'])
    sic= cis.iloc[i]['SIC']
    
    bias_r2=np.append(bias_r2,(r2[pd.to_datetime(r2['Date (YYYY-MM-DD)'])==date]['Mean Ice Concentration (%)']-sic).values)
    bias_asi=np.append(bias_asi,(asi[pd.to_datetime(asi['Date (YYYY-MM-DD)'])==date]['Mean Ice Concentration (%)']-sic).values)

print('RSAT-2 bias (%): ' + str(np.nanmean(bias_r2)))
print('ASI bias (%): ' + str(np.nanmean(bias_asi)))
print('RSAT-2 RMSE (%): ' + str(np.sqrt(np.nanmean(bias_r2**2))))
print('ASI RMSE (%): ' + str(np.sqrt(np.nanmean(bias_asi**2))))
# Out:
# RSAT-2 bias (%): -0.4021337816085189
# ASI bias (%): -4.039268046759609
# RSAT-2 RMSE (%): 8.412943190250207
# ASI RMSE (%): 10.815901848767634

# %% [markdown]
# ## Observations:
# 1. Mean bias better for R2 than ASI
# 2. RMSE slightly better for R2 tha ASI
# 3. ASI never drops to 0% where R2 does.
# 4. Some severe overestimation of sea ice in summer (especially summer 2015).
# 5. R2 seems to do better during the melt season than ASI (atmospheric effects greater for ASI?)
# 6. R2 seems to have issues in the early season (when ice starts to form). Could be due to the fact that the training data does not include stages of development of young ice.

# %% [markdown]
# ## Figure: Monthly bias distribution for the ASI SIC and RSAT-2 products

# %%
fig1, ax1=plt.subplots(figsize=(15,10))

data1=[]
data2=[]

for i in range(1,13):

    data1.append(bias_r2[(np.isnan(bias_r2)==0) & (cis['Date'].iloc[1:].dt.month==i)])
    data2.append(bias_asi[(np.isnan(bias_asi)==0) & (cis['Date'].dt.month==i)])
    
bp1 = ax1.boxplot(data1, whis = [5, 95], sym='',patch_artist = True, 
                     widths = 0.3, positions = np.arange(0.8, 12, 1))
for box in bp1['boxes']:
    box.set(facecolor = 'darkred')
bp2 = ax1.boxplot(data2, whis = [5, 95], sym='',patch_artist = True,
                     widths = 0.3, positions = np.arange(1.2, 13, 1))
for box in bp2['boxes']:
    box.set(facecolor = 'teal')
ax1.plot([0,13],[0,0],'-k')
ax1.set_xlim(0,13)
ax1.set_ylim(-50,50)
ax1.set_xticks(np.arange(1, 13,1))
ax1.set_xticklabels(np.arange(1,13).tolist(),fontsize=22,fontweight='bold')
ax1.set_yticklabels(np.arange(-60,50,20).tolist(),fontsize=22,fontweight='bold')
ax1.set_xlabel('Month',fontsize=26,fontweight='bold')
ax1.set_ylabel('Bias (%)',fontsize=26,fontweight='bold')
ax1.legend([bp1["boxes"][0], bp2["boxes"][0]], ['RSAT-2', 'ASI'], loc='upper right', fontsize=26)

# %% [markdown]
# ## Observations
# 1. RSAT-2 bias a lot less spread out than ASI.
# 2. RSAT-2 closer to 0 for the winter months (Jan to June).
# 3. More error during break-up (June/July) in ASI.
# 4. Larger error during freeze-up during October-November for ASI but smaller for December.

# %% [markdown]
# ## Potential Figure: Time series of the sea ice concentration of Coronation Gulf for the CIS regional charts, the RSAT-2 CNN classification and ASI Classified SIC products.
#
# Note: The classified SIC product counts all pixels having a concentration of 50% or more as ice and divides it by the total number of pixels.
# This is similar to the RSAT-2 procuct where it counts all the pixels with a prediction of 50% or more of being ice and divides it by the total number of pixels

# %%
fig, ax = plt.subplots(figsize=(15,10))

ax.fill_between(cis['Date'],cis['SIC'])
ax.plot(asi['Date (YYYY-MM-DD)'],asi['Classified Ice Concentration (%)'],color='orange', linewidth=2)
ax.plot(pd.to_datetime(r2['Date (YYYY-MM-DD)']),r2['Mean Ice Concentration (%)'],'+k', markeredgewidth=2)
ax.set_ylim(0,120)
ax.set_xlim(datetime(2008,6,1), datetime(2020,8,31))
ax.set_xticklabels(np.arange(2008,2022,2).tolist(),fontsize=24,fontweight='bold')
ax.set_yticklabels(np.arange(0,120,20),fontsize=24,fontweight='bold')
ax.legend(['ASI', 'RSAT-2', 'CIS'], fontsize=22, loc='upper center', ncol=3)
ax.set_ylabel('SIC (%)', fontsize=24, fontweight='bold')
# Out:
# Text(0, 0.5, 'SIC (%)')

# %% [markdown]
# ## Observations:
# 1. The classified ASI product is a lot better during the winter season.
# 2. The ASI product still never reaches 0.

# %%
bias_r2=np.array([])
bias_asi=np.array([])

for i in range(len(cis)):
    
    date=pd.to_datetime(cis.iloc[i]['Date'])
    sic= cis.iloc[i]['SIC']
    
    bias_r2=np.append(bias_r2,(r2[pd.to_datetime(r2['Date (YYYY-MM-DD)'])==date]['Mean Ice Concentration (%)']-sic).values)
    bias_asi=np.append(bias_asi,(asi[pd.to_datetime(asi['Date (YYYY-MM-DD)'])==date]['Classified Ice Concentration (%)']-sic).values)

print('RSAT-2 bias (%): ' + str(np.nanmean(bias_r2)))
print('ASI bias (%): ' + str(np.nanmean(bias_asi)))
print('RSAT-2 RMSE (%): ' + str(np.sqrt(np.nanmean(bias_r2**2))))
print('ASI RMSE (%): ' + str(np.sqrt(np.nanmean(bias_asi**2))))
# Out:
# RSAT-2 bias (%): -0.4021337816085189
# ASI bias (%): -1.14067401981626
# RSAT-2 RMSE (%): 8.412943190250207
# ASI RMSE (%): 9.378362241501359

# %% [markdown]
# ## Observations:
# 1. ASI still has a higher RMSE/Bias. Might be due to the summer period.
# 2. Both RSAT-2 and ASI products seem to struggle more in detecting water

# %% [markdown]
# ## Potential Figure: Monthly bias distribution for the ASI classified SIC and RSAT-2 products
#
# Note: Not sure that using the classified ASI product is a good comparison since we are comparing a 25km product to a 1km product (RSAT-2)... The other point is that the RSAT-2 product was trained on 100% or 0% SIC samples and nothing in between. This comparison is not to say that the RSAT-2 product is better, it is more to evaluate the potential of it to assess images with a mix of ice and water.

# %%
fig1, ax1=plt.subplots(figsize=(15,10))

data1=[]
data2=[]

for i in range(1,13):

    data1.append(bias_r2[(np.isnan(bias_r2)==0) & (cis['Date'].iloc[1:].dt.month==i)])
    data2.append(bias_asi[(np.isnan(bias_asi)==0) & (cis['Date'].dt.month==i)])
    
bp1 = ax1.boxplot(data1, whis = [5, 95], sym='',patch_artist = True, 
                     widths = 0.3, positions = np.arange(0.8, 12, 1))
for box in bp1['boxes']:
    box.set(facecolor = 'darkred')
bp2 = ax1.boxplot(data2, whis = [5, 95], sym='',patch_artist = True,
                     widths = 0.3, positions = np.arange(1.2, 13, 1))
for box in bp2['boxes']:
    box.set(facecolor = 'teal')
ax1.plot([0,13],[0,0],'-k')
ax1.set_xlim(0,13)
ax1.set_ylim(-50,50)
ax1.set_xticks(np.arange(1, 13,1))
ax1.set_xticklabels(np.arange(1,13).tolist(),fontsize=22,fontweight='bold')
ax1.set_yticklabels(np.arange(-60,50,20).tolist(),fontsize=22,fontweight='bold')
ax1.set_xlabel('Month',fontsize=26,fontweight='bold')
ax1.set_ylabel('Bias (%)',fontsize=26,fontweight='bold')
ax1.legend([bp1["boxes"][0], bp2["boxes"][0]], ['RSAT-2', 'ASI'], loc='upper right', fontsize=26)

# %% [markdown]
# ## Observations:
# 1. As expected from previous figure: the winter months, the ASI classified product performs a lot better than the RSAT-2 product.
# 2. Median values are still higher for the summer months for ASI.
